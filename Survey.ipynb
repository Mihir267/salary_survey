# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the csv file
df = pd.read_csv("/content/drive/MyDrive/MOCK_final/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.csv")

# %%
df.head()
# Out:
#             Timestamp How old are you?  What industry do you work in?  \
# 0  4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22            25-34              Computing or Tech
# 2  4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41            25-34                     Nonprofits
# 4  4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
df.size
# Out:
# 504360

# %%
df.shape
# Out:
# (28020, 18)

# %%
df.describe()
# Out:
#        How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.
# count                                       2.073800e+04
# mean                                        1.818263e+04
# std                                         8.346158e+05
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         2.000000e+03
# 75%                                         1.000000e+04
# max                                         1.200000e+08

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull()
# Out:
#        Timestamp  How old are you?  What industry do you work in?  Job title  \
# 0          False             False                          False      False
# 1          False             False                          False      False
# 2          False             False                          False      False
# 3          False             False                          False      False
# 4          False             False                          False      False
# ...          ...               ...                            ...        ...
# 28015      False             False                          False      False
# 28016      False             False                          False      False
# 28017      False             False                          False      False
# 28018      False             False                          False      False
# 28019      False             False                          False      False
#
# ...

# %%
#changing name of columns which is needed

# %%
df = df.rename(columns={'How old are you?':'Age','Job title':'Job_role'})

# %%
df = df.rename({'What industry do you work in?':'Industry'}, axis=1)

# %%
df = df.rename(columns={'If your job title needs additional context, please clarify here:' : 'Additional_context','Please indicate the currency':'Currency'})

# %%
df = df.rename({"What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)": 'Annual_salary'},axis=1)

# %%
df = df.rename({'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.':'Aditional_salary'}, axis=1)

# %%
df = df.rename(columns={'If "Other," please indicate the currency here:' : 'other_currency','If your income needs additional context, please provide it here:' : 'Additional_contex'})

# %%
df = df.rename({'If "Other," please indicate the currency here:' :'other_currency'}, axis=1)

# %%
df.head()
# Out:
#             Timestamp    Age                       Industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                    Job_role Additional_context Annual_salary  \
# 0        Research and Instruction Librarian                NaN        55,000
# 1  Change & Internal Communications Manager                NaN        54,600
# 2                      Marketing Specialist                NaN        34,000
# 3                           Program Manager                NaN        62,000
# 4                        Accounting Manager                NaN        60,000
#
#    Aditional_salary Currency If "Other," please indicate the currency here:   \
# ...

# %%
df = df.rename(columns={'What country do you work in?' : 'Country',"'If you're in the U.S., what state do you work in?" : 'US_State'})

# %%
df.rename({'What city do you work in?': 'City'},axis=1,inplace=True)

# %%
df.rename({'How many years of professional work experience do you have overall?':'Experience'}, axis=1,inplace=True)

# %%
df.rename({'How many years of professional work experience do you have in your field?' : 'Professional_experience'}, axis=1,inplace=True)

# %%
df.rename({'What is your highest level of education completed?':'Education'}, axis=1,inplace=True)

# %%
df.rename({'What is your gender?':'Gender'}, axis=1,inplace=True)

# %%
df.rename({'What is your race? (Choose all that apply.)':'Race'},axis=1,inplace=True)

# %%
df.head()
# Out:
#             Timestamp    Age                       Industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                    Job_role Additional_context Annual_salary  \
# 0        Research and Instruction Librarian                NaN        55,000
# 1  Change & Internal Communications Manager                NaN        54,600
# 2                      Marketing Specialist                NaN        34,000
# 3                           Program Manager                NaN        62,000
# 4                        Accounting Manager                NaN        60,000
#
#    Aditional_salary Currency If "Other," please indicate the currency here:   \
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Industry', 'Job_role', 'Additional_context',
#        'Annual_salary', 'Aditional_salary', 'Currency',
#        'If "Other," please indicate the currency here: ', 'Additional_contex',
#        'Country', 'If you're in the U.S., what state do you work in?', 'City',
#        'Experience', 'Professional_experience', 'Education', 'Gender', 'Race'],
#       dtype='object')

# %%
df.rename({'If "Other," please indicate the currency here: ' : 'other_currency'}, axis=1, inplace=True)

# %%
df.rename({'''If you're in the U.S., what state do you work in?''' : 'US_state'},axis=1,inplace=True)

# %%
df.head()
# Out:
#             Timestamp    Age                       Industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                    Job_role Additional_context Annual_salary  \
# 0        Research and Instruction Librarian                NaN        55,000
# 1  Change & Internal Communications Manager                NaN        54,600
# 2                      Marketing Specialist                NaN        34,000
# 3                           Program Manager                NaN        62,000
# 4                        Accounting Manager                NaN        60,000
#
#    Aditional_salary Currency other_currency Additional_contex         Country  \
# ...

# %%
#cheackin all the null values
df.isnull().sum()
# Out:
# Timestamp                      0
# Age                            0
# Industry                      73
# Job_role                       1
# Additional_context         20770
# Annual_salary                  0
# Aditional_salary            7282
# Currency                       0
# other_currency             27818
# Additional_contex          24981
# Country                        0
# US_state                    5007
# City                          77
# Experience                     0
# Professional_experience        0
# Education                    218
# Gender                       169
# Race                         173
# dtype: int64

# %%
#Drop columns which is not needed

df.drop('Aditional_salary',axis=1,inplace=True)

# %%
df.drop('other_currency',axis=1,inplace=True)

# %%
df.drop('Additional_contex', axis=1, inplace=True)

# %%
df.drop('Race',axis=1,inplace=True)

# %%
df.head()
# Out:
#             Timestamp    Age                       Industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                    Job_role Additional_context Annual_salary  \
# 0        Research and Instruction Librarian                NaN        55,000
# 1  Change & Internal Communications Manager                NaN        54,600
# 2                      Marketing Specialist                NaN        34,000
# 3                           Program Manager                NaN        62,000
# 4                        Accounting Manager                NaN        60,000
#
#   Currency         Country        US_state         City    Experience  \
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                      0
# Age                            0
# Industry                      73
# Job_role                       1
# Additional_context         20770
# Annual_salary                  0
# Currency                       0
# Country                        0
# US_state                    5007
# City                          77
# Experience                     0
# Professional_experience        0
# Education                    218
# Gender                       169
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 26315

# %%
df.drop('Additional_context',axis=1,inplace=True)

# %%
df.drop(['US_state'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Timestamp                    0
# Age                          0
# Industry                    73
# Job_role                     1
# Annual_salary                0
# Currency                     0
# Country                      0
# City                        77
# Experience                   0
# Professional_experience      0
# Education                  218
# Gender                     169
# dtype: int64

# %%
df.head()
# Out:
#             Timestamp    Age                       Industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                    Job_role Annual_salary Currency  \
# 0        Research and Instruction Librarian        55,000      USD
# 1  Change & Internal Communications Manager        54,600      GBP
# 2                      Marketing Specialist        34,000      USD
# 3                           Program Manager        62,000      USD
# 4                        Accounting Manager        60,000      USD
#
#           Country         City    Experience Professional_experience  \
# 0   United States       Boston     5-7 years               5-7 years
# ...

# %%
#featching Date from Timestamp

df['Date'] = pd.to_datetime(df['Timestamp']).dt.date

# %%
#featching Year from the Timestamp

df['Year'] = pd.to_datetime(df['Timestamp']).dt.year

# %%
df.head()
# Out:
#             Timestamp    Age                       Industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                    Job_role Annual_salary Currency  \
# 0        Research and Instruction Librarian        55,000      USD
# 1  Change & Internal Communications Manager        54,600      GBP
# 2                      Marketing Specialist        34,000      USD
# 3                           Program Manager        62,000      USD
# 4                        Accounting Manager        60,000      USD
#
#           Country         City    Experience Professional_experience  \
# 0   United States       Boston     5-7 years               5-7 years
# ...

# %%
#featching Time from Timestamp

df['Time'] = pd.to_datetime(df['Timestamp']).dt.time

# %%
df.head()
# Out:
#             Timestamp    Age                       Industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                    Job_role Annual_salary Currency  \
# 0        Research and Instruction Librarian        55,000      USD
# 1  Change & Internal Communications Manager        54,600      GBP
# 2                      Marketing Specialist        34,000      USD
# 3                           Program Manager        62,000      USD
# 4                        Accounting Manager        60,000      USD
#
#           Country         City    Experience Professional_experience  \
# 0   United States       Boston     5-7 years               5-7 years
# ...

# %%
df.drop('Timestamp',axis=1,inplace=True)

# %%
df.head()
# Out:
#      Age                       Industry  \
# 0  25-34   Education (Higher Education)
# 1  25-34              Computing or Tech
# 2  25-34  Accounting, Banking & Finance
# 3  25-34                     Nonprofits
# 4  25-34  Accounting, Banking & Finance
#
#                                    Job_role Annual_salary Currency  \
# 0        Research and Instruction Librarian        55,000      USD
# 1  Change & Internal Communications Manager        54,600      GBP
# 2                      Marketing Specialist        34,000      USD
# 3                           Program Manager        62,000      USD
# 4                        Accounting Manager        60,000      USD
#
#           Country         City    Experience Professional_experience  \
# 0   United States       Boston     5-7 years               5-7 years
# 1  United Kingdom    Cambridge  8 - 10 years               5-7 years
# 2              US  Chattanooga   2 - 4 years             2 - 4 years
# ...

# %%
df.isnull().sum()
# Out:
# Age                          0
# Industry                    73
# Job_role                     1
# Annual_salary                0
# Currency                     0
# Country                      0
# City                        77
# Experience                   0
# Professional_experience      0
# Education                  218
# Gender                     169
# Date                         0
# Year                         0
# Time                         0
# dtype: int64

# %%
#convert Null values in 'Unknown'

df[['Industry','Job_role','City','Education','Gender']] = df[['Industry','Job_role','City','Education','Gender']].replace(np.nan,'Unknown')

# %%
df.isnull().sum()
# Out:
# Age                        0
# Industry                   0
# Job_role                   0
# Annual_salary              0
# Currency                   0
# Country                    0
# City                       0
# Experience                 0
# Professional_experience    0
# Education                  0
# Gender                     0
# Date                       0
# Year                       0
# Time                       0
# dtype: int64

# %% [markdown]
# <h1> Which industry pays the most? <h1>

# %%
#Featching top industry

df['Industry'].value_counts().iloc[1:11]
# Out:
# Education (Higher Education)            2462
# Nonprofits                              2418
# Health care                             1892
# Government and Public Administration    1887
# Accounting, Banking & Finance           1801
# Engineering or Manufacturing            1694
# Marketing, Advertising & PR             1132
# Law                                     1097
# Business or Consulting                   851
# Education (Primary/Secondary)            834
# Name: Industry, dtype: int64

# %%
#featching top industry which pays most

df1 = df.groupby('Industry').Annual_salary.max().sort_index(ascending=True).iloc[1:11]

# %%
df1
# Out:
# Industry
#  Veterinary medicine                    155000
# "Government Relations" (Lobbying)       65,000
# Academia                                56,400
# Academia                                15,000
# Academia - STEM                          32000
# Academia / Research                     68,500
# Academia--cell and molecular biology    48,000
# Academic Medicine                       55,000
# Academic Press Production               42,000
# Academic Publishing                     55,500
# Name: Annual_salary, dtype: object

# %%
pd.DataFrame(df1)
# Out:
#                                      Annual_salary
# Industry
#  Veterinary medicine                        155000
# "Government Relations" (Lobbying)           65,000
# Academia                                    56,400
# Academia                                    15,000
# Academia - STEM                              32000
# Academia / Research                         68,500
# Academia--cell and molecular biology        48,000
# Academic Medicine                           55,000
# Academic Press Production                   42,000
# Academic Publishing                         55,500

# %%
sorted_data = df1.sort_values(ascending=False)

# %%
sorted_data
# Out:
# Industry
# Academia / Research                     68,500
# "Government Relations" (Lobbying)       65,000
# Academia                                56,400
# Academic Publishing                     55,500
# Academic Medicine                       55,000
# Academia--cell and molecular biology    48,000
# Academic Press Production               42,000
# Academia - STEM                          32000
#  Veterinary medicine                    155000
# Academia                                15,000
# Name: Annual_salary, dtype: object

# %%
df2 = pd.DataFrame(sorted_data)

# %%
df2
# Out:
#                                      Annual_salary
# Industry
# Academia / Research                         68,500
# "Government Relations" (Lobbying)           65,000
# Academia                                    56,400
# Academic Publishing                         55,500
# Academic Medicine                           55,000
# Academia--cell and molecular biology        48,000
# Academic Press Production                   42,000
# Academia - STEM                              32000
#  Veterinary medicine                        155000
# Academia                                    15,000

# %%
df.head()
# Out:
#      Age                       Industry  \
# 0  25-34   Education (Higher Education)
# 1  25-34              Computing or Tech
# 2  25-34  Accounting, Banking & Finance
# 3  25-34                     Nonprofits
# 4  25-34  Accounting, Banking & Finance
#
#                                    Job_role Annual_salary Currency  \
# 0        Research and Instruction Librarian        55,000      USD
# 1  Change & Internal Communications Manager        54,600      GBP
# 2                      Marketing Specialist        34,000      USD
# 3                           Program Manager        62,000      USD
# 4                        Accounting Manager        60,000      USD
#
#           Country         City    Experience Professional_experience  \
# 0   United States       Boston     5-7 years               5-7 years
# 1  United Kingdom    Cambridge  8 - 10 years               5-7 years
# 2              US  Chattanooga   2 - 4 years             2 - 4 years
# ...

# %% [markdown]
# <h1>top 10 salary provide by Computing or Tech in United kingdom
#  <h1>

# %%
df3 = df[(df['Annual_salary'] >= '50000') & (df['Industry'] == 'Computing or Tech')].iloc[1:11]

# %%
df3
# Out:
#        Age           Industry                                    Job_role  \
# 53   35-44  Computing or Tech          Managed Services Sales Coordinator
# 74   35-44  Computing or Tech                                 Tech Writer
# 95   45-54  Computing or Tech            senior web application developer
# 99   55-64  Computing or Tech                              Chief Engineer
# 179  35-44  Computing or Tech                technical support specialist
# 191  25-34  Computing or Tech                             Systems Analyst
# 197  35-44  Computing or Tech                     Senior Technical Writer
# 207  25-34  Computing or Tech  Strategic Operations and Programme Manager
# 233  45-54  Computing or Tech                            Business Analyst
# 356  25-34  Computing or Tech                   Salesforce Administrator
#
#     Annual_salary Currency                   Country                  City  \
# 53         72,000      USD             United States                  Troy
# ...

# %% [markdown]
# <h1>Top 10 Industry <h1>

# %%
ind = df['Industry'].value_counts().iloc[1:11]

# %%
pd.DataFrame(ind)
# Out:
#                                       Industry
# Education (Higher Education)              2462
# Nonprofits                                2418
# Health care                               1892
# Government and Public Administration      1887
# Accounting, Banking & Finance             1801
# Engineering or Manufacturing              1694
# Marketing, Advertising & PR               1132
# Law                                       1097
# Business or Consulting                     851
# Education (Primary/Secondary)              834

# %%
plt.figure(figsize = (8,10))

#using sns barplot
sns.barplot(x = ind.values, y=ind.index, palette='viridis')

#naming Title
plt.title("Top 10 Industry")

##naming x and y axis
plt.xlabel('Number of industry')
plt.ylabel('Industry')

plt.show()
# Out:
# <ipython-input-84-4747e438f0ef>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = ind.values, y=ind.index, palette='viridis')

# %%
df.head()
# Out:
#      Age                       Industry  \
# 0  25-34   Education (Higher Education)
# 1  25-34              Computing or Tech
# 2  25-34  Accounting, Banking & Finance
# 3  25-34                     Nonprofits
# 4  25-34  Accounting, Banking & Finance
#
#                                    Job_role Annual_salary Currency  \
# 0        Research and Instruction Librarian        55,000      USD
# 1  Change & Internal Communications Manager        54,600      GBP
# 2                      Marketing Specialist        34,000      USD
# 3                           Program Manager        62,000      USD
# 4                        Accounting Manager        60,000      USD
#
#           Country         City    Experience Professional_experience  \
# 0   United States       Boston     5-7 years               5-7 years
# 1  United Kingdom    Cambridge  8 - 10 years               5-7 years
# 2              US  Chattanooga   2 - 4 years             2 - 4 years
# ...

# %% [markdown]
# <h1> Top 10 woman who gets paid more than 60000 salary

# %%
df[(df['Gender'] == 'Woman') & (df['Annual_salary'] >= '60000')].iloc[1:11]
# Out:
#       Age                              Industry  \
# 11  35-44          Education (Higher Education)
# 16  35-44                Business or Consulting
# 18  35-44                Business or Consulting
# 20  25-34                           Health care
# 22  35-44                            Nonprofits
# 23  35-44  Government and Public Administration
# 29  25-34          Engineering or Manufacturing
# 35  35-44          Education (Higher Education)
# 37  25-34         Accounting, Banking & Finance
# 38  35-44  Government and Public Administration
#
#                                              Job_role Annual_salary Currency  \
# 11  Deputy Title IX Coordinator/ Assistant Directo...        62,000      USD
# 16                                Executive Assistant        85,000      USD
# 18                                     Senior Manager        98,000      USD
# 20                            Data Programmer Analyst        74,000      USD
# ...
